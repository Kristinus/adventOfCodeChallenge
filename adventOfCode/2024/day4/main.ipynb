# %%
import sys
import numpy as np
import math
import operator
import functools
import json
from pprint import pprint
from tqdm.notebook import tqdm, trange

# %%
def part1(arr: list[str]):
    _len = len(arr[0])
    total = 0
    XMAS = "XMAS"
    for i in range(len(arr)):
        for j in range(_len):
            for off, l in enumerate(XMAS):
                if 0 <= i+off and i+off < len(arr) and 0 <= j and j < _len:
                    if arr[i+off][j] != XMAS[off]:
                        break
                else:
                    break
            else:
                total += 1
                
            for off, l in enumerate(XMAS):
                if 0 <= i-off and i-off < len(arr) and 0 <= j and j < _len:
                    if arr[i-off][j] != XMAS[off]:
                        break
                else:
                    break
            else:
                total += 1
                
            for off, l in enumerate(XMAS):
                if 0 <= i and i < len(arr) and 0 <= j+off and j+off < _len:
                    if arr[i][j+off] != XMAS[off]:
                        break
                else:
                    break
            else:
                total += 1
                
            for off, l in enumerate(XMAS):
                if 0 <= i and i < len(arr) and 0 <= j-off and j-off < _len:
                    if arr[i][j-off] != XMAS[off]:
                        break
                else:
                    break
            else:
                total += 1
                
            for off, l in enumerate(XMAS):
                if 0 <= i+off and i+off < len(arr) and 0 <= j+off and j+off < _len:
                    if arr[i+off][j+off] != XMAS[off]:
                        break
                else:
                    break
            else:
                total += 1
                
            for off, l in enumerate(XMAS):
                if 0 <= i-off and i-off < len(arr) and 0 <= j-off and j-off < _len:
                    if arr[i-off][j-off] != XMAS[off]:
                        break
                else:
                    break
            else:
                total += 1
                
            for off, l in enumerate(XMAS):
                if 0 <= i+off and i+off < len(arr) and 0 <= j-off and j-off < _len:
                    if arr[i+off][j-off] != XMAS[off]:
                        break
                else:
                    break
            else:
                total += 1
                
            for off, l in enumerate(XMAS):
                if 0 <= i-off and i-off < len(arr) and 0 <= j+off and j+off < _len:
                    if arr[i-off][j+off] != XMAS[off]:
                        break
                else:
                    break
            else:
                total += 1
        
        
    return total

# %%
from collections import defaultdict

def part2(arr: list[str]):
    _len = len(arr[0])
    total = 0
    for i in range(1,len(arr)-1):
        for j in range(1,_len-1):
            if arr[i][j] == "A":
                criss = False
                for _i in (-1, 1):
                    for _j in (-1, 1):
                        if arr[i+_i][j+_j] == "M":
                            if arr[i-_i][j-_j] == "S":
                                if not criss:
                                    criss = True
                                else:
                                    total += 1
            
    return total

# %%
if __name__ == "__main__":
    file = sys.argv[-1] if sys.argv[-1].endswith(".txt") else "input.txt"
    with open(file, "r") as f:
        arr = f.read().splitlines()

        print(part1(arr))
        print(part2(arr))
# Out:
# 2578
# 1972
